# %% [markdown]
# Tasks to be performed:
# - Using pandas import the dataset as dataframe
# - Install the mixtend library to use apriory and association rule mining
# - Using the apriori algorithm generate a list of item frequently brought together.
# - Generate the association rules for the given items from apriori algorithm

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"G:\Intellipaat-20220522T063246Z-001\Intellipaat Assignments\Unsupervised Learning Assignments\5.-Association-Rule-Mining-converted\Retail.csv",encoding = "latin-1")
df.head()
# Out:
#                                           Unnamed: 0  Unnamed: 1  \
# 0                     Transactions from the Database         NaN
# 1      1 : { Pencils, Markers, Highlighters, Papers}         NaN
# 2                             2 : {Markers, Erasers}         NaN
# 3  3 : {Stapler Pins, Papers, Erasers, Card Holde...         NaN
# 4                 4 : {Papers, Erasers, Cad Holders}         NaN
#
#      Unnamed: 2                                   Unnamed: 3 Unnamed: 4  \
# 0           NaN  #Transactions in which\n the item is bought    Support
# 1       Pencils                                            2        0.2
# 2       Markers                                            6        0.6
# 3  Highlighters                                            3        0.3
# 4        Papers                                            4        0.4
#
#   Unnamed: 5
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
 pip install apyori
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5979 sha256=f447756985ee424269a115828f9a1b8364bfe65b6a0186a3860ccb2c75f7fd2f
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\1b\02\6c\a45230be8603bd95c0a51cd2b289aefdd860c1a100eab73661
# Successfully built apyori
# ...

# %%
from apyori import apriori

# %%
df.shape
# Out:
# (18, 6)

# %%
#converting dataframe into list of lists
l=[]
for i in range(1,18):
    l.append([str(df.values[i,j]) for j in range(0,6)])

# %%
#applying apriori algorithm
association_rules = apriori(l, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
association_results = list(association_rules)

# %%
for i in range(0, len(association_results)):
    print(association_results[i][0])
# Out:
# frozenset({'#Transactions in which\n the item is bought', 'Construct item-sets with items that satisfy minimum support'})
# frozenset({'Support\nP(MarkersÇErasers)', '#Transactions in which\n the item is bought'})
# frozenset({'1 : { Pencils, Markers, Highlighters, Papers}', '0.2'})
# frozenset({'2', '0.2'})
# frozenset({'7 : {Markers, Erasers}', '0.2'})
# frozenset({'9 : {StaplerPins, Post-it, Markers, Erasers}', '0.2'})
# frozenset({'Card Holders', '0.2'})
# frozenset({'Envelop', '0.2'})
# frozenset({'Pencils', '0.2'})
# frozenset({'3', '0.3'})
# frozenset({'0.3', '3 : {Stapler Pins, Papers, Erasers, Card Holders, Highlighters}'})
# frozenset({'6 : {Envelop}', '0.3'})
# frozenset({'0.3', '8 : {Pencils, Markers, StaplerPins, Post-it, Highlighter, Papers, Erasers}'})
# frozenset({'0.3', 'Highlighters'})
# frozenset({'0.3', 'Post-it'})
# frozenset({'Stapler Pins', '0.3'})
# frozenset({'0.4', '4'})
# frozenset({'0.4', '4 : {Papers, Erasers, Cad Holders}'})
# ...

# %%
for item in association_results:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])
    # second index of the inner list
    print("Support: " + str(item[1]))
    # third index of the list located at 0th position
    # of the third index of the inner list
    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("-----------------------------------------------------")
# Out:
# Rule: #Transactions in which
#  the item is bought -> Construct item-sets with items that satisfy minimum support
# Support: 0.058823529411764705
# Confidence: 1.0
# Lift: 17.0
# -----------------------------------------------------
# Rule: Support
# P(MarkersÇErasers) -> #Transactions in which
#  the item is bought
# Support: 0.058823529411764705
# Confidence: 1.0
# Lift: 17.0
# -----------------------------------------------------
# Rule: 1 : { Pencils, Markers, Highlighters, Papers} -> 0.2
# Support: 0.058823529411764705
# Confidence: 0.3333333333333333
# Lift: 5.666666666666666
# -----------------------------------------------------
# Rule: 2 -> 0.2
# Support: 0.17647058823529413
# Confidence: 1.0
# Lift: 5.666666666666666
# -----------------------------------------------------
# Rule: 7 : {Markers, Erasers} -> 0.2
# Support: 0.058823529411764705
# Confidence: 0.3333333333333333
# Lift: 5.666666666666666
# -----------------------------------------------------
# ...
